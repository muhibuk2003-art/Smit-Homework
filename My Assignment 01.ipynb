# %% [markdown]
# # Question#1

# %%
a=20
b=5
print(a/b)
# Out:
# 4.0

# %% [markdown]
# # Question#2

# %%
c="M MUHIB ULLAH KHAN"
print(c)
# Out:
# M MUHIB ULLAH KHAN

# %%
c.lower()
# Out:
# 'm muhib ullah khan'

# %% [markdown]
# # Question#3

# %%
d="hello world from python"
print(d.title())
# Out:
# Hello World From Python

# %% [markdown]
# # Question#4

# %%
x=10
y=3
print(x%y)
# Out:
# 1

# %% [markdown]
# # Question#5

# %%
text="PYTHON"
print(text.lower())
# Out:
# python

# %% [markdown]
# # Question#6

# %%
string="data science"
print(len(string))
# Out:
# 12

# %% [markdown]
# # Question#7

# %%
num=7
print(pow(num,2))
# Out:
# 49

# %% [markdown]
# # Question#8

# %%
string="hello"
print(string*3)
# Out:
# hellohellohello

# %% [markdown]
# # Question#9

# %%
a=15
b=10
if(a>b):{
print("a is greater")}
else:{
print("b is greater")}
# Out:
# a is greater

# %% [markdown]
# # Question#10

# %%
text="i love python programming"
print(text.capitalize())
# Out:
# I love python programming
